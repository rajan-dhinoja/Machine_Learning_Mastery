# %% [markdown]
# <a href="https://colab.research.google.com/github/rajan-dhinoja/Machine_Learning_Mastery/blob/main/Maths_for_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

np.set_printoptions(precision = 3)

# %% [markdown]
# # Vector Tutorial...

# %%
plt.quiver(0,0,4,5, scale_units = 'xy', angles = 'xy', scale = 1, color = 'r')
plt.xlim(-5,8)
plt.ylim(-5,8)
plt.show()

# %%
vector_1 = np.random.randint(-10,10,3)
vector_2 = np.random.randint(-10,10,3)
# vector_1 = np.array([1,2,3])
# vector_2 = np.array([4,5,6])

print("Vector 1: ",vector_1)
print("Vector 2: ",vector_2, "\n")

plt.quiver(0,0,vector_1[0], vector_1[1], scale_units = 'xy', angles = 'xy', scale = 1, color = 'r')
plt.quiver(0,0,vector_2[1], vector_2[2], scale_units = 'xy', angles = 'xy', scale = 1, color = 'b')
plt.xlim(-12,12)
plt.ylim(-12,12)
plt.show()
# Out:
# Vector 1:  [-4 -8  0]
# Vector 2:  [6 9 3]

# %% [markdown]
# ## Vector Arithmetic:-

# %%
print(f"Vector Addition: \t{vector_1 + vector_2}")
print(f"Vector Subtraction: \t{vector_1 - vector_2}")
print(f"Scaler Multiplication: \t{vector_1 * 25}")
print(f"Vector Multiplication: \t{vector_1 * vector_2}")
print(f"Vector Division: \t{vector_1 / vector_2}")
# Out:
# Vector Addition: 	[2 1 3]
# Vector Subtraction: 	[-10 -17  -3]
# Scaler Multiplication: 	[-100 -200    0]
# Vector Multiplication: 	[-24 -72   0]
# Vector Division: 	[-0.667 -0.889  0.   ]

# %% [markdown]
# ## Vector Product

# %%
print(f"Dot Product: \t{np.dot(vector_1, vector_2)}")
print(f"Cross Product: \t{np.cross(vector_1, vector_2)}")
# Out:
# Dot Product: 	-96
# Cross Product: 	[-24  12  12]

# %% [markdown]
# ## Projection of vector_1 on vector_2
# (proj_1_on_2) = (1x2/||2||**2)x2

# %%
magnitude_of_2 = np.sqrt(sum(vector_2**2))
# magnitude_of_2 = np.sqrt(np.dot(vector_2, vector_2))

projection = (np.dot(vector_1, vector_2) / magnitude_of_2) * vector_2
print(f"Projection of vector_1 on vector_2: k{projection}")
# Out:
# Projection of vector_1 on vector_2: k[-51.314 -76.971 -25.657]

# %% [markdown]
# # Matrix Tutorial...

# %%
s = np.random.randint(2, 10)

matrix_1 = np.random.randint(0, 10, size=(s,s))
print(f"Matrix 1: \n {matrix_1}")

matrix_2 = np.random.randint(0, 10, size=(s,s))
# Out:
# Matrix 1:
#  [[9 3 0 9 3 9]
#  [2 0 7 8 1 5]
#  [0 2 7 0 0 4]
#  [1 7 9 9 9 2]
#  [7 8 7 2 2 2]
#  [1 4 5 3 8 9]]

# %% [markdown]
# ## Matrix Arithmetic:-
